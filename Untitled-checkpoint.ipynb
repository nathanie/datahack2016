# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %% [markdown]
# first import the data

# %%
meetings= pd.read_csv("~/data/datahack2016/input/meetings_train.csv")
port_visits= pd.read_csv("~/data/datahack2016/input/port_visits_train.csv")
labels= pd.read_csv("~/data/datahack2016/input/vessels_labels_train.csv")

# %%
vessels_type = labels['type']

# %%
vessels_type.value_counts()
# Out:
# Bulk Carrier        7404
# Container Vessel    4057
# Tug                 3419
# Oil Tanker          2981
# Fishing Vessel      2200
# Passenger Vessel    1038
# Reefer               543
# Name: type, dtype: int64

# %%
ports = port_visits['port_id']

# %%
port_visits_counts = pd.DataFrame(ports.value_counts())

# %%
port_visits_counts.
# Out:
#                           port_id
# 5358fc78b68ca120a07dbcfc    16420
# 5358fc78b68ca120a07dbce5    15895
# 5358fc78b68ca120a07dbcfb    11443
# 5358fc78b68ca120a07dbc77     9368
# 5358fc78b68ca120a07dbc71     7654

# %%
labels.head()
# Out:
#                   vessel_id              type
# 0  56d8509fe4b099a29d073a62  Container Vessel
# 1  56d950d9e4b0e60539c6b71d  Container Vessel
# 2  56d85a07e4b0fb60063969d8      Bulk Carrier
# 3  56d85736e4b030f1c0039905        Oil Tanker
# 4  56db31f9e4b02c227b748c14               Tug

# %%
types = vessels_type.unique()

# %%
vessels_type.shape
# Out:
# (21642,)

# %%
ports_labels = pd.merge(port_visits,labels,left_on='ves_id',right_on= 'vessel_id')

# %%
ports_labels.
# Out:
# (3590,)

# %%
groups = ports_labels.groupby('vessel_id')
# Out:
#                           ves_id           start_time  duration_min  \
# 0       56db7bf5e4b087b8d90a9d5e  2016-03-10 07:55:05          1641
# 1       56db7bf5e4b087b8d90a9d5e  2016-04-16 23:14:21          2066
# 2       56db7bf5e4b087b8d90a9d5e  2016-05-01 09:51:43          4307
# 3       56db7bf5e4b087b8d90a9d5e  2016-02-16 00:08:36             0
# 4       56db7bf5e4b087b8d90a9d5e  2016-01-27 01:29:21          2815
# 60      56d88f20e4b0e60539c699ca  2016-03-31 07:37:35           730
# 61      56d88f20e4b0e60539c699ca  2016-03-10 05:28:48           931
# 62      56d88f20e4b0e60539c699ca  2016-03-16 03:22:06          1559
# 63      56d88f20e4b0e60539c699ca  2016-01-02 16:46:49           925
# 64      56d88f20e4b0e60539c699ca  2016-02-01 22:03:03           829
# 99      56d96b7be4b0cdbda2acd645  2016-06-16 07:24:58           141
# 100     56d96b7be4b0cdbda2acd645  2016-03-13 18:32:04             0
# 101     56d96b7be4b0cdbda2acd645  2016-03-13 09:26:32           461
# ...

# %%
# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, label=name)
ax.legend()

plt.show()

# %%
unique_ports = port_visits['port_id'].unique()

# %%
plt.scatter(ports_labels['Lat'],port_visits['Long'])
